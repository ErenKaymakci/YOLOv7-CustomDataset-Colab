# %% [markdown]
# # **YOLOv7 Custom Dataset Training**
# ## Drive'ı Projeye Dahil Etme

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## Gereksinimlerin Kurulması

# %%
# !git clone https://github.com/WongKinYiu/yolov7
# %cd yolov7
# !pip install -qr requirements.txt

# %% [markdown]
# ## Datayı Çıkarma
# Eğitimde ve testte kullanılacak fotoğrafları istediğiniz fotoğrafları zip dosyasına sıkıştırıp Drive'a yükleyin. Benim zip dosyamın içeriği şu şekilde:
# <ul type="none">
#       v7-data/
#       <li>├─ data.yaml </li>
#      <li> └─ train </li>
#        <li><dd> └─ images </dd></li>
#        <li><dd> └─ labels </dd></li>
#       <li>└─ val </li>
#         <li><dd> └─ images </dd></li>
#         <li><dd> └─ labels </dd></li>
#
#
#
# </ul>
#
# data.yaml dosyanız yoksa endişe etmeyin zipin içerisine yaml dosyası oluşturup boş bir şekilde atın düzenlemeyi beraber yapalım.
# ## YAML Dosyası Düzenleme
# yaml dosyasının içeriği bu şekilde olmalıdır:
# ```
# train: ../data/train/images
# val: ../data/val/images
#
# nc: 5
# names: [...]
# ```
# <ul type="disc">
# <li> <strong>nc</strong> : sınıf sayınız </li>
#
# <li> <strong>names</strong> : sınıf isimleriniz örn: [insan, kedi, köpek] </li>
#
# <li>
#
# ```
# train: ../{klasör adı}/train/images
# val: ../{klasör adı}/val/images
# ```
#
# Ekstra test klasörünüz varsa val satırının altına:
#
# ``` test: ../test/images ```
#  vb. şeklinde ekleyebilirsiniz
#
# </li>
#
# </ul>
# <br>
#
# ### Artık zip dosyasını Colab'e çıkarabiliriz ⬇️

# %%
# !unzip -q /content/drive/MyDrive/YOLOv7/v7-data.zip -d ../

# %% [markdown]
# ## Kullanılacak Ağırlıkların İndirilmesi
# Bu kısımda ben "yolov7.pt"yi kullanmak istediğim için onu indirdim. https://github.com/WongKinYiu/yolov7/releases kısmından bakıp istediğiniz pt dosyasını indirebilirsiniz.

# %%
# %cd /content/yolov7
# !wget "https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7.pt"

# %% [markdown]
# ## Eğitim

# %%
# !python train.py --batch 16 --cfg cfg/training/yolov7.yaml --epochs 10 --data /content/v7-data/data.yaml --weights 'yolov7.pt' --device 0

# %% [markdown]
# ## Test

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --conf 0.1 --source {img path}

# %% [markdown]
# ## Ağırlıkları Drive'a Çekme

# %%
# %cd ..
# !cp  ./yolov7/runs/train/exp4/weights/best.pt ./drive/MyDrive/ 
# !cp ./yolov7/runs/train/exp4/weights/last.pt ./drive/MyDrive/
